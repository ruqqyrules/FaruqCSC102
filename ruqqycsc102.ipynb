# %% [markdown]
# # NAME:FARUQ SODIA
# # MAT NO:20120612205
# # EMAIL:FARUQ.SODIA@PAU.EDU.NG
# # EXERCISE 1

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %%
num1 = float(input("enter a number"))
if num1 > 17:
    result = float(num1 -17)
    print(2 *result)
# Out:
# enter a number22
# 10.0

# %%
b=14
a=17
c=b-a

print(c)
# Out:
# -3

# %% [markdown]
# # EXERCISE 2

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %%
c=1
d=2
e=3
f=c+d+e
if c!=d!=e:
    print(f)
# Out:
# 6

# %%
g=3
h=3
f=3
i=g+h+f
if g==h==f:
    print(i*3)
# Out:
# 27

# %% [markdown]
# # EXERCISE 3

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %%
a = float(input("Enter a Number:"))
b = float(input("Enter a Number:"))
if a == b:
    print("True")
elif a + b == 5 :
    print("True")
elif a - b == 5:
    print("True")
else:
    print("False")
# Out:
# Enter a Number:7
# Enter a Number:2
# True

# %% [markdown]
# # EXERCISE 4

# %% [markdown]
# ![Picture4.png](attachment:Picture4.png)

# %%
a = int(input("Input first number: "))
b = int(input("Input second number: "))
c = int(input("Input third number: "))

x1 = min(a,b,c)
x2 = max(a,b,c)
x3 = (a + b + c) - x1 - x2
print("Numbers in sorted order: ", x1, x2, x3)
# Out:
# Input first number: 8
# Input second number: 3
# Input third number: 7
# Numbers in sorted order:  3 8 7

# %% [markdown]
# # EXERCISE 5

# %% [markdown]
# ![Picture5.png](attachment:Picture5.png)

# %%
def sum_of_cubes(k):
    k -= 1
    total = 0
    while k > 0:
        total += k * k * k
        k -= 1
    return total
print("Sum of cubes: ",sum_of_cubes(6))
# Out:
# Sum of cubes:  225
